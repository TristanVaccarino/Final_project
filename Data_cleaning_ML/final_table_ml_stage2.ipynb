# %%
#initial imports
import pandas as pd
from datetime import datetime
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Bring in CSV file
df = pd.read_csv("final_table_ml.csv")

# %%
# Check file 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20969 entries, 0 to 20968
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   business_postal_code      20969 non-null  int64
#  1   Unnamed: 0                20969 non-null  int64
#  2   population                20969 non-null  int64
#  3   avg_income                20969 non-null  int64
#  4   inspection_id             20969 non-null  object
#  5   inspection_date           20969 non-null  object
#  6   inspection_score          20969 non-null  float64
#  7   inspection_type           20969 non-null  object
#  8   violation_description     20969 non-null  object
#  9   risk_category             20969 non-null  object
#  10  Neighborhoods             20969 non-null  float64
#  11  Current Police Districts  20969 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 1.9+ MB

# %%
#Check df
df
# Out:
#        business_postal_code  Unnamed: 0  population   avg_income  \
# 0                     94127           1        20624       95313
# 1                     94127           1        20624       95313
# 2                     94127           1        20624       95313
# 3                     94127           1        20624       95313
# 4                     94127           1        20624       95313
# ...                     ...         ...          ...         ...
# 20964                 94101          31            0           0
# 20965                 94101          31            0           0
# 20966                 94101          31            0           0
# 20967                 94101          31            0           0
# 20968                 94101          31            0           0
#
#         inspection_id         inspection_date  inspection_score  \
# 0      38798_20170928  09/28/2017 12:00:00 AM              94.0
# ...

# %%
#Remove Unnamed column
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
#Check df
df
# Out:
#        business_postal_code  population   avg_income   inspection_id  \
# 0                     94127        20624       95313  38798_20170928
# 1                     94127        20624       95313   5796_20170825
# 2                     94127        20624       95313   2808_20170621
# 3                     94127        20624       95313   4630_20170304
# 4                     94127        20624       95313   2808_20190103
# ...                     ...          ...         ...             ...
# 20964                 94101            0           0  65856_20190117
# 20965                 94101            0           0  65856_20190828
# 20966                 94101            0           0  65856_20170821
# 20967                 94101            0           0  65856_20170821
# 20968                 94101            0           0  65856_20170821
#
#               inspection_date  inspection_score        inspection_type  \
# ...

# %%
# Drop columns
#drop initial columns 
df = df.drop(columns=["inspection_type"])

# %%
# Check file after drop
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20969 entries, 0 to 20968
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   business_postal_code      20969 non-null  int64
#  1   population                20969 non-null  int64
#  2   avg_income                20969 non-null  int64
#  3   inspection_id             20969 non-null  object
#  4   inspection_date           20969 non-null  object
#  5   inspection_score          20969 non-null  float64
#  6   violation_description     20969 non-null  object
#  7   risk_category             20969 non-null  object
#  8   Neighborhoods             20969 non-null  float64
#  9   Current Police Districts  20969 non-null  float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 1.6+ MB

# %%
# Check shape
df.shape
# Out:
# (20969, 10)

# %%
# See new table
df.head()
# Out:
#    business_postal_code  population   avg_income   inspection_id  \
# 0                 94127        20624       95313  38798_20170928
# 1                 94127        20624       95313   5796_20170825
# 2                 94127        20624       95313   2808_20170621
# 3                 94127        20624       95313   4630_20170304
# 4                 94127        20624       95313   2808_20190103
#
#           inspection_date  inspection_score  \
# 0  09/28/2017 12:00:00 AM              94.0
# 1  08/25/2017 12:00:00 AM              98.0
# 2  06/21/2017 12:00:00 AM              81.0
# 3  03/04/2017 12:00:00 AM              96.0
# 4  01/03/2019 12:00:00 AM              74.0
#
#                                violation_description risk_category  \
# 0                     Improper or defective plumbing      Low Risk
# 1                              Improper food storage      Low Risk
# 2                           Other low risk violation      Low Risk
# ...

# %%
# for column in df[["inspection_date"]]: 
#     if column.startswith("01"):
#         print ("January")
#     elif column.startswith("02"):
#         replacewith()

# %%
#Replace date with corrilating month
j=df['inspection_date'].str.startswith('01')
df.loc[j,'inspection_date']='January'

#Replace date with corrilating month
f=df['inspection_date'].str.startswith('02')
df.loc[f,'inspection_date']='February'

#Replace date with corrilating month
m=df['inspection_date'].str.startswith('03')
df.loc[m,'inspection_date']='March'

#Replace date with corrilating month
a=df['inspection_date'].str.startswith('04')
df.loc[a,'inspection_date']='April'

#Replace date with corrilating month
ma=df['inspection_date'].str.startswith('05')
df.loc[ma,'inspection_date']='May'

#Replace date with corrilating month
ju=df['inspection_date'].str.startswith('06')
df.loc[ju,'inspection_date']='June'

#Replace date with corrilating month
jl=df['inspection_date'].str.startswith('07')
df.loc[jl,'inspection_date']='July'

#Replace date with corrilating month
au=df['inspection_date'].str.startswith('08')
df.loc[au,'inspection_date']='August'

#Replace date with corrilating month
s=df['inspection_date'].str.startswith('09')
df.loc[s,'inspection_date']='September'

#Replace date with corrilating month
o=df['inspection_date'].str.startswith('10')
df.loc[o,'inspection_date']='October'

#Replace date with corrilating month
n=df['inspection_date'].str.startswith('11')
df.loc[n,'inspection_date']='November'

#Replace date with corrilating month
d=df['inspection_date'].str.startswith('12')
df.loc[d,'inspection_date']='December'

df.head()
# Out:
#    business_postal_code  population   avg_income   inspection_id  \
# 0                 94127        20624       95313  38798_20170928
# 1                 94127        20624       95313   5796_20170825
# 2                 94127        20624       95313   2808_20170621
# 3                 94127        20624       95313   4630_20170304
# 4                 94127        20624       95313   2808_20190103
#
#   inspection_date  inspection_score  \
# 0       September              94.0
# 1          August              98.0
# 2            June              81.0
# 3           March              96.0
# 4         January              74.0
#
#                                violation_description risk_category  \
# 0                     Improper or defective plumbing      Low Risk
# 1                              Improper food storage      Low Risk
# 2                           Other low risk violation      Low Risk
# 3  Food safety certificate or food handler card n...      Low Risk
# ...

# %%
# Save changes
df.to_csv('final_table_ml_stage2.csv', index=False)
